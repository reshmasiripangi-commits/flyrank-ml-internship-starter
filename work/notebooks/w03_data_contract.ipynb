# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reshmasiripangi-commits/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# Each row represents one content item with its search-related features and performance metrics. The data is collected over a 90-day time window, as shown by columns such as impressions_90d, log_clicks_90d, and log_sessions_90d.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/processed/refresh_feature_vector.csv")

print("Rows:", len(df))
print(df.head())
# Out:
# Rows: 30000
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         0.0
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... trend_direction trend_pct  is_declining_label  \
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Features:
# - search_volume
# - competition
# - competition_level
# - cpc
# - content_type
# - main_intent
# - word_count
# - char_count
#
# Label:
# - measurable_opportunity
#
# Context:
# - content_id
# - client_id
# - provider_used
# - model_used
#
# Excluded:
# - log_clicks_90d
# - log_sessions_90d
# - log_ai_sessions_90d
#
# These excluded fields contain historical performance information that may introduce data leakage if used for prediction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(df.columns.tolist())
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct', 'is_declining_label', 'log_impressions_90d', 'log_clicks_90d', 'log_sessions_90d', 'log_ai_sessions_90d', 'has_clicks', 'has_ai_sessions', 'measurable_opportunity']

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# The dataset contains one row per content item. Missing values were checked using pandas, and the number of unique content items confirms the dataset grain.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/processed/refresh_feature_vector.csv")

print("Number of rows:", len(df))

print("\nMissing values:")
print(df.isnull().sum())

print("\nUnique content items:")
print(df["content_id"].nunique())
# Out:
# Number of rows: 30000
#
# Missing values:
# content_id                0
# client_id                 0
# search_volume             0
# competition               0
# competition_level         0
# cpc                       0
# content_type              0
# main_intent               0
# word_count                0
# char_count                0
# provider_used             0
# model_used                0
# impressions_90d           0
# clicks_90d                0
# pageviews_90d             0
# sessions_90d              0
# users_90d                 0
# engaged_sessions_90d      0
# ai_sessions_90d           0
# scroll_events_90d         0
# days_with_impressions     0
# days_with_sessions        0
# impressions_last_30d      0
# clicks_last_30d           0
# sessions_last_30d         0
# impressions_prev_30d      0
# clicks_prev_30d           0
# sessions_prev_30d         0
# content_age_days          0
# age_tier                  0
# age_tier_order            0
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# This dataset contains historical search information collected over a 90-day period. Future trends, seasonal changes, and external factors are not included, so predictions may not always generalize to future data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
